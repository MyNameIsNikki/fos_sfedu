# %% [markdown]
# # ЛР-6. Vision Transformer ViT
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Загрузка данных
#
# Загрузите CSU101 или подмножество ImageNet.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## ViT fine-tuning
#
# Загрузите предобученный ViT-Base. Замените head. Дообучите.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Карты внимания
#
# Визуализируйте self-attention maps для разных слоёв.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Сравнение с CNN
#
# Сравните ViT с ResNet-50 по accuracy и FPS.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Patch size
#
# Экспериментируйте с patch_size=16 vs 32.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
