# %% [markdown]
# # ЛР-5. Генерация изображений DCGAN
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Загрузка данных
#
# Загрузите CelebA или CIFAR-10. Создайте DataLoader.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Generator
#
# Реализуйте архитектуру генератора DCGAN.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Discriminator
#
# Реализуйте архитектуру дискриминатора.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Цикл обучения
#
# Реализуйте цикл обучения GAN. Фиксируйте loss.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Визуализация
#
# Покажите генерируемые изображения каждые N эпох.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Стабилизация
#
# Примените label smoothing, LeakyReLU. Оцените FID.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
