# %% [markdown]
# # ЛР-4. Семантическая сегментация U-Net
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Загрузка данных
#
# Загрузите CamVid или Cityscapes. Реализуйте pipeline аугментации.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## U-Net реализация
#
# Реализуйте U-Net с бэкбоном ResNet-34. Настройте функцию потерь.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## FCN реализация
#
# Реализуйте FCN. Сравните с U-Net по IoU.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Обучение
#
# Обучите с Cross-Entropy и Dice Loss. Сравните результаты.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Визуализация
#
# Покажите исходное изображение, маску, предсказание для нескольких примеров.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
