# %% [markdown]
# # ЛР-9. Распознавание текста CRNN
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Загрузка данных
#
# Загрузите IIIT5K или SVHN. Синтезируйте дополнительные данные.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## CNN backbone
#
# Реализуйте VGG-like или ResNet backbone.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## BiLSTM + CTC
#
# Реализуйте BiLSTM и CTC Loss.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Обучение
#
# Обучите CRNN. Фиксируйте CER, WER.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Тестирование
#
# Протестируйте на реальных изображениях. Проанализируйте ошибки.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
