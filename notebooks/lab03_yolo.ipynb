# %% [markdown]
# # ЛР-3. Детекция объектов YOLO
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Подготовка датасета
#
# Соберите 100-200 изображений. Разметьте в формате YOLO.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Обучение
#
# Обучите YOLOv8/v11 на своём датасете. Настройте гиперпараметры.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Оценка
#
# Вычислите Precision, Recall, mAP@0.5, mAP@0.5:0.95.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Инференс
#
# Проведите детекцию на тестовых изображениях и видео. Визуализируйте bounding boxes.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Анализ ошибок
#
# Проанализируйте false positive и false negative.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
