# %% [markdown]
# # ЛР-1. Классическое детектирование по Виоле-Джонса
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Загрузка данных
#
# Загрузите датасет FDDB или Caltech Pedestrians. Визуализируйте примеры.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Каскад Хаара
#
# Загрузите предобученный каскад из OpenCV. Примените к тестовым изображениям. Оцените TPR, FPR.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Обучение каскада
#
# Подготовьте положительные и отрицательные выборки. Обучите каскад с opencv_traincascade.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## HOG + SVM
#
# Извлеките HOG-дескрипторы. Обучите LinearSVC. Сравните с каскадом Хаара по mAP.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Визуализация
#
# Покажите примеры детекций обоими методами. Постройте Precision-Recall кривые.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
