# %% [markdown]
# # ЛР-8. Мультимодальная модель (Captioning)
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Загрузка данных
#
# Загрузите COCO Captions или Flickr8k.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Архитектура
#
# Реализуйте кодировщик изображений (ViT/ResNet) + декодер (Transformer/LSTM).

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Проекционный слой
#
# Реализуйте проекцию image features → text embedding space.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Обучение
#
# Обучите с cross-entropy loss (teacher forcing).

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Генерация
#
# Генерируйте подписи с beam search. Оцените BLEU, ROUGE.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
