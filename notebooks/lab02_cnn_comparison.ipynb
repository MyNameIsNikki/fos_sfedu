# %% [markdown]
# # ЛР-2. Сравнительный анализ свёрточных архитектур
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Загрузка данных
#
# Загрузите CIFAR-10 или CSU101. Создайте DataLoader с аугментацией.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Базовое воспроизведение
#
# Загрузите предобученный ResNet50. Замените head. Дообучите. Зафиксируйте accuracy.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## SE block
#
# Реализуйте Squeeze-and-Excitation блок. Встройте в ResNet. Обучите.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## ECA block
#
# Реализуйте ECA блок. Сравните с SE по точности и числу параметров.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Inverted bottleneck
#
# Реализуйте блок MobileNetV2. Постройте график accuracy vs params.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
