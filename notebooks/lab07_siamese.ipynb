# %% [markdown]
# # ЛР-7. Метрическое обучение (Siamese Networks)
#
# Стартовый блокнот. Заполните ячейки с кодом в соответствии с заданием.

# %% [markdown]
# ## Подготовка среды
#
# Установите необходимые библиотеки:

# %%
# !pip install -q torch torchvision opencv-python matplotlib numpy

# %% [markdown]
# ## Загрузка данных
#
# Загрузите LFW. Сформируйте триплеты (anchor, positive, negative).

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Архитектура
#
# Постройте сиамскую сеть на основе ResNet-18 (без head).

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Triplet Loss
#
# Реализуйте Triplet Loss с hard mining.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Обучение
#
# Обучите модель. Визуализируйте динамику loss.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Визуализация эмбеддингов
#
# Примените t-SNE или UMAP. Оцените accuracy, ROC-AUC.

# %%
# TODO: реализуйте этот раздел
pass

# %% [markdown]
# ## Выводы
#
# Проанализируйте полученные результаты, сравните методы, укажите ограничения.

# %%
# TODO: напишите выводы
